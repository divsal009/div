# %% [markdown]
# <a href="https://colab.research.google.com/github/divsal009/div/blob/master/DataVisualization%26Analysis_using_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#to draw descriptive graph
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
boston_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/boston_train.csv')

# %%
boston_df
# Out:
#          CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0     2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1    13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2     0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3     0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4     0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6
# ..        ...   ...    ...    ...    ...   ...     ...  ...      ...   ...
# 395   0.23912   0.0   9.69  0.585  6.019  65.3  2.4091  391     19.2  21.2
# 396   0.04560   0.0  13.89  0.550  5.888  56.0  3.1121  276     16.4  23.3
# 397   1.38799   0.0   8.14  0.538  5.950  82.0  3.9900  307     21.0  13.2
# 398   7.36711   0.0  18.10  0.679  6.193  78.1  1.9356  666     20.2  11.0
# 399   0.14150   0.0   6.91  0.448  6.169   6.6  5.7209  233     17.9  25.3
#
# [400 rows x 10 columns]

# %% [markdown]
# # line plot

# %%
plt.figure(figsize=(18,9))
plt.plot(boston_df['AGE'])
plt.title('Line Plot')
plt.xlabel('Indexes')
plt.ylabel('AGE')
# Out:
# Text(0, 0.5, 'AGE')

# %% [markdown]
# bar **graph**

# %%
x=[1,3,5,7]
y=[10,30,50,70]
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x1=[1,3,5,7]
y1=[10,30,50,70]
x2=[11,13,15,17]
y2=[21,24,26,29]
plt.bar(x1,y1,color='red',label='lab1')
plt.bar(x2,y2,color='green',label='lab2')
plt.legend()
plt.savefig('/content/bar.png')
plt.show()

# %% [markdown]
# ## **histogram**

# %%
#continous distribution of data

# %%
plt.hist(boston_df['MEDV'])
# Out:
# (array([ 18.,  48.,  63., 113.,  68.,  35.,  20.,   7.,   8.,  20.]),
#  array([ 5. ,  9.5, 14. , 18.5, 23. , 27.5, 32. , 36.5, 41. , 45.5, 50. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(boston_df['MEDV'],bins=20)
# Out:
# (array([ 9.,  9., 13., 35., 30., 33., 62., 51., 60.,  8., 21., 14., 10.,
#         10.,  6.,  1.,  4.,  4.,  2., 18.]),
#  array([ 5.  ,  7.25,  9.5 , 11.75, 14.  , 16.25, 18.5 , 20.75, 23.  ,
#         25.25, 27.5 , 29.75, 32.  , 34.25, 36.5 , 38.75, 41.  , 43.25,
#         45.5 , 47.75, 50.  ]),
#  <a list of 20 Patch objects>)

# %%
plt.figure(figsize=(12,8))
plt.hist(boston_df['MEDV'], bins=20)
plt.title('Histogram Plot')
plt.xlabel('Range of MEDV')
plt.ylabel('Frequency')
plt.show()

# %%
#iris

# %%
iris_df=pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/iris.csv',sep=',')

# %%
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# scatter **plot**(relnship/coreln btn 2 data)

# %%
plt.scatter(x=iris_df['sepal_length'],y=iris_df['sepal_width'],marker='^')

# %%
plt.scatter(x=iris_df['sepal_length'],y=iris_df['sepal_width'],marker='x')

# %%
plt.scatter(x=iris_df['sepal_length'],y=iris_df['sepal_width'],marker='^',c='green',s=100)
plt.scatter(x=iris_df['sepal_length'],y=iris_df['petal_length'],marker='^',c='red',s=200)
plt.show()

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(13,10))
plt.scatter(x = iris_df['sepal_length'], y = iris_df['sepal_width'], marker = 'x', c = 'red')
plt.scatter(x = iris_df['sepal_length'], y = iris_df['petal_length'], marker = 'x', s = 40)
plt.show()

# %% [markdown]
# Scatterplot using **seaborn**

# %%
plt.figure(figsize=(13,10))
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data=iris_df,hue='sepal_width',size='sepal_width',marker='s')
plt.show()

# %%
plt.figure(figsize=(13,10))
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data = iris_df, hue='sepal_width', size = 'sepal_width')

plt.figure(figsize=(13,10))
sns.scatterplot(x = 'sepal_length', y = 'sepal_width', data = iris_df, hue='species', marker = 's')
plt.show()

# %% [markdown]
# density **plot**
