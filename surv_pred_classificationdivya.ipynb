# %% [markdown]
# <a href="https://colab.research.google.com/github/divsal009/div/blob/master/surv_pred_classificationdivya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline
import tensorflow as tf
import keras.backend as K
# import keras
# from ensorflow import keras

# %%
from keras import layers
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout,Maximum,Flatten
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
# from tensorflow.keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
# from tensorflow.keras.layers.convolutional import Conv2D, Conv2DTranspose,Conv3D,Conv3DTranspose,UpSampling2D
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D,MaxPooling3D,AveragePooling2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from sklearn.utils import class_weight
from keras.models import Sequential
import nibabel as nib

# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
path1 = "E:\MICCAI_BraTS_2018_Data_Training\survival_data.csv"
#print(os.listdir(path))
# Brats18_CBICA_ANP_1
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import csv
#import pickle

#from joblib import dump

age_dict = {}
days_dict = {}




with open(path1, mode='r') as csv_file:
    csv_reader = csv.reader(csv_file,delimiter = ',')
    line_count = 0
    a = 0
    b = 0
    c = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(row)
            key = row[0]
            age = row[1]
            days = row[2]
            age_dict[key] = float(age)
            days_dict[key] = int(days)
            if int(days) < 250:
                a += 1
            elif (int(days) >= 250 and int(days) <= 500):
                b += 1
            else:
                c += 1
            line_count+=1

    print(f'Processed {line_count} lines.')
    #age_m = np.zeros((1,1))
    print(a,b,c)
# Out:
# Column names are BraTS18ID, Age, Survival, ResectionStatus
# ['Brats18_TCIA08_167_1', '74.907', '153', 'NA']
# ['Brats18_TCIA08_242_1', '66.479', '147', 'NA']
# ['Brats18_TCIA08_319_1', '64.86', '254', 'NA']
# ['Brats18_TCIA08_469_1', '63.899', '519', 'NA']
# ['Brats18_TCIA08_218_1', '57.345', '346', 'NA']
# ['Brats18_TCIA08_406_1', '78.745', '82', 'NA']
# ['Brats18_TCIA08_280_1', '57.362', '508', 'NA']
# ['Brats18_TCIA08_105_1', '66.627', '77', 'NA']
# ['Brats18_TCIA08_278_1', '50.501', '1458', 'NA']
# ['Brats18_TCIA06_247_1', '76.699', '244', 'NA']
# ['Brats18_TCIA06_372_1', '74.521', '213', 'NA']
# ['Brats18_TCIA06_165_1', '51.756', '5', 'NA']
# ['Brats18_TCIA06_409_1', '69.266', '99', 'NA']
# ['Brats18_TCIA06_184_1', '61.167', '434', 'NA']
# ['Brats18_TCIA05_277_1', '70.367', '232', 'NA']
# ['Brats18_TCIA05_478_1', '59.255', '30', 'NA']
# ['Brats18_TCIA04_437_1', '46.953', '333', 'NA']
# ['Brats18_TCIA04_361_1', '75.973', '476', 'NA']
# ['Brats18_TCIA04_192_1', '75.962', '121', 'NA']
# ['Brats18_TCIA04_479_1', '56.4', '372', 'NA']
# ['Brats18_TCIA04_111_1', '75.263', '626', 'NA']
# ['Brats18_TCIA04_343_1', '52.679', '296', 'NA']
# ['Brats18_TCIA04_149_1', '36.852', '448', 'NA']
# ['Brats18_TCIA03_474_1', '61.408', '635', 'NA']
# ['Brats18_TCIA03_419_1', '70.592', '327', 'NA']
# ['Brats18_TCIA03_199_1', '48.825', '1282', 'NA']
# ['Brats18_TCIA03_133_1', '63.762', '382', 'NA']
# ['Brats18_TCIA03_296_1', '60.427', '22', 'NA']
# ['Brats18_TCIA03_257_1', '69.326', '425', 'NA']
# ['Brats18_TCIA03_498_1', '59.282', '467', 'NA']
# ['Brats18_TCIA03_138_1', '71.874', '82', 'NA']
# ['Brats18_TCIA03_338_1', '76.425', '468', 'NA']
# ['Brats18_TCIA03_265_1', '59.584', '103', 'NA']
# ['Brats18_TCIA03_375_1', '60', '946', 'NA']
# ['Brats18_TCIA03_121_1', '30.408', '747', 'NA']
# ['Brats18_TCIA02_274_1', '54.967', '357', 'NA']
# ['Brats18_TCIA02_473_1', '61.022', '175', 'NA']
# ['Brats18_TCIA02_322_1', '57.362', '621', 'NA']
# ['Brats18_TCIA02_179_1', '46.677', '405', 'NA']
# ['Brats18_TCIA02_368_1', '62.562', '317', 'NA']
# ['Brats18_TCIA02_135_1', '69.364', '828', 'NA']
# ['Brats18_TCIA02_471_1', '76.614', '111', 'NA']
# ['Brats18_TCIA02_394_1', '64.247', '616', 'NA']
# ['Brats18_TCIA02_300_1', '64.378', '127', 'NA']
# ['Brats18_TCIA02_151_1', '47.973', '1731', 'NA']
# ['Brats18_TCIA02_118_1', '47.321', '104', 'NA']
# ['Brats18_TCIA02_226_1', '73.578', '329', 'NA']
# ['Brats18_TCIA02_455_1', '54.844', '424', 'NA']
# ['Brats18_TCIA02_283_1', '74.836', '262', 'NA']
# ['Brats18_TCIA02_430_1', '53.866', '71', 'NA']
# ['Brats18_TCIA02_321_1', '81.211', '67', 'NA']
# ['Brats18_TCIA02_314_1', '40.353', '362', 'NA']
# ['Brats18_TCIA02_290_1', '43.112', '737', 'NA']
# ['Brats18_TCIA02_377_1', '63.762', '812', 'NA']
# ['Brats18_TCIA02_198_1', '54.279', '394', 'NA']
# ['Brats18_TCIA02_331_1', '84.844', '187', 'NA']
# ['Brats18_TCIA02_491_1', '81.112', '82', 'NA']
# ['Brats18_TCIA01_150_1', '51.115', '1489', 'NA']
# ['Brats18_TCIA01_335_1', '54.474', '355', 'NA']
# ['Brats18_TCIA01_411_1', '42.904', '822', 'NA']
# ['Brats18_TCIA01_203_1', '45.926', '268', 'NA']
# ['Brats18_TCIA01_231_1', '63.805', '1561', 'NA']
# ['Brats18_TCIA01_390_1', '63.575', '634', 'NA']
# ['Brats18_TCIA01_235_1', '57.973', '804', 'NA']
# ['Brats18_TCIA01_499_1', '50.082', '600', 'NA']
# ['Brats18_TCIA01_412_1', '68.759', '291', 'NA']
# ['Brats18_TCIA01_448_1', '44.449', '199', 'NA']
# ['Brats18_TCIA01_401_1', '78.792', '448', 'NA']
# ['Brats18_TCIA01_147_1', '61.416', '209', 'NA']
# ['Brats18_TCIA01_378_1', '74.145', '110', 'NA']
# ['Brats18_TCIA01_201_1', '60.729', '430', 'NA']
# ['Brats18_TCIA01_429_1', '54.986', '86', 'NA']
# ['Brats18_TCIA01_186_1', '33.888', '370', 'NA']
# ['Brats18_TCIA01_460_1', '18.975', '630', 'NA']
# ['Brats18_TCIA01_190_1', '61.526', '322', 'NA']
# ['Brats18_TCIA01_425_1', '56.208', '558', 'NA']
# ['Brats18_2013_11_1', '29.12', '150', 'GTR']
# ['Brats18_2013_27_1', '68.02', '120', 'GTR']
# ['Brats18_CBICA_BHM_1', '62.03', '436', 'STR']
# ['Brats18_CBICA_BHB_1', '55.595', '510', 'GTR']
# ['Brats18_CBICA_AZH_1', '54.915', '401', 'GTR']
# ['Brats18_CBICA_AZD_1', '46.258', '448', 'GTR']
# ['Brats18_CBICA_AYW_1', '49.874', '734', 'NA']
# ['Brats18_CBICA_AYU_1', '63.781', '58', 'GTR']
# ['Brats18_CBICA_AYI_1', '65.921', '387', 'GTR']
# ['Brats18_CBICA_AYA_1', '74.836', '50', 'GTR']
# ['Brats18_CBICA_AXW_1', '79.211', '191', 'GTR']
# ['Brats18_CBICA_AXQ_1', '66.282', '114', 'GTR']
# ['Brats18_CBICA_AXO_1', '56.301', '394', 'NA']
# ['Brats18_CBICA_AXN_1', '85.762', '345', 'GTR']
# ['Brats18_CBICA_AXM_1', '66.934', '438', 'STR']
# ['Brats18_CBICA_AXL_1', '74.63', '168', 'GTR']
# ['Brats18_CBICA_AXJ_1', '27.811', '1767', 'GTR']
# ['Brats18_CBICA_AWI_1', '46.551', '375', 'GTR']
# ['Brats18_CBICA_AWH_1', '52.764', '139', 'GTR']
# ['Brats18_CBICA_AWG_1', '55.532', '180', 'GTR']
# ['Brats18_CBICA_AVV_1', '72.293', '387', 'GTR']
# ['Brats18_CBICA_AVJ_1', '45.244', '614', 'GTR']
# ['Brats18_CBICA_AVG_1', '63.359', '579', 'GTR']
# ['Brats18_CBICA_AUR_1', '70.252', '12', 'GTR']
# ['Brats18_CBICA_AUQ_1', '60.816', '1337', 'NA']
# ['Brats18_CBICA_AUN_1', '68.504', '376', 'GTR']
# ['Brats18_CBICA_ATX_1', '36.784', '1592', 'GTR']
# ['Brats18_CBICA_ATV_1', '62.159', '453', 'GTR']
# ['Brats18_CBICA_ATP_1', '51.589', '385', 'GTR']
# ['Brats18_CBICA_ATF_1', '68.726', '152', 'GTR']
# ['Brats18_CBICA_ATD_1', '69.178', '355', 'GTR']
# ['Brats18_CBICA_ATB_1', '71.126', '208', 'GTR']
# ['Brats18_CBICA_ASY_1', '66.51', '610', 'STR']
# ['Brats18_CBICA_ASW_1', '68.359', '239', 'GTR']
# ['Brats18_CBICA_ASV_1', '54.751', '597', 'GTR']
# ['Brats18_CBICA_ASU_1', '81.285', '85', 'STR']
# ['Brats18_CBICA_ASO_1', '52.348', '265', 'STR']
# ['Brats18_CBICA_ASN_1', '39.488', '407', 'STR']
# ['Brats18_CBICA_ASK_1', '77.337', '522', 'GTR']
# ['Brats18_CBICA_ASH_1', '46.57', '660', 'GTR']
# ['Brats18_CBICA_ASG_1', '57.71', '208', 'STR']
# ['Brats18_CBICA_ASE_1', '46.814', '318', 'STR']
# ['Brats18_CBICA_ASA_1', '63.764', '210', 'STR']
# ['Brats18_CBICA_ARZ_1', '54.825', '871', 'STR']
# ['Brats18_CBICA_ARW_1', '44.416', '495', 'STR']
# ['Brats18_CBICA_ARF_1', '75.312', '726', 'GTR']
# ['Brats18_CBICA_AQZ_1', '63.345', '286', 'STR']
# ['Brats18_CBICA_AQY_1', '57.718', '229', 'STR']
# ['Brats18_CBICA_AQV_1', '53.362', '84', 'GTR']
# ['Brats18_CBICA_AQU_1', '72.879', '30', 'STR']
# ['Brats18_CBICA_AQT_1', '75.978', '172', 'GTR']
# ['Brats18_CBICA_AQR_1', '71.37', '89', 'GTR']
# ['Brats18_CBICA_AQQ_1', '69.992', '33', 'STR']
# ['Brats18_CBICA_AQP_1', '46.452', '1283', 'GTR']
# ['Brats18_CBICA_AQO_1', '67.86', '473', 'GTR']
# ['Brats18_CBICA_AQN_1', '63.192', '488', 'STR']
# ['Brats18_CBICA_AQJ_1', '66.074', '170', 'STR']
# ['Brats18_CBICA_AQG_1', '53.605', '466', 'STR']
# ['Brats18_CBICA_AQD_1', '73.036', '32', 'STR']
# ['Brats18_CBICA_AQA_1', '76.367', '106', 'GTR']
# ['Brats18_CBICA_APZ_1', '60.063', '336', 'STR']
# ['Brats18_CBICA_APY_1', '45.548', '203', 'STR']
# ['Brats18_CBICA_APR_1', '62.704', '23', 'STR']
# ['Brats18_CBICA_AOZ_1', '46.666', '331', 'GTR']
# ['Brats18_CBICA_AOP_1', '67.833', '332', 'GTR']
# ['Brats18_CBICA_AOO_1', '44.162', '350', 'GTR']
# ['Brats18_CBICA_AOH_1', '56.921', '576', 'GTR']
# ['Brats18_CBICA_AOD_1', '60.581', '55', 'NA']
# ['Brats18_CBICA_ANZ_1', '68.049', '287', 'GTR']
# ['Brats18_CBICA_ANP_1', '61.605', '486', 'GTR']
# ['Brats18_CBICA_ANI_1', '58.258', '439', 'GTR']
# ['Brats18_CBICA_ANG_1', '55.759', '368', 'GTR']
# ['Brats18_CBICA_AMH_1', '62.614', '169', 'GTR']
# ['Brats18_CBICA_AME_1', '51.734', '359', 'GTR']
# ['Brats18_CBICA_ALX_1', '59.693', '698', 'GTR']
# ['Brats18_CBICA_ALU_1', '65.899', '495', 'GTR']
# ['Brats18_CBICA_ALN_1', '60.942', '421', 'STR']
# ['Brats18_CBICA_ABY_1', '48.367', '515', 'GTR']
# ['Brats18_CBICA_ABO_1', '56.419', '1155', 'GTR']
# ['Brats18_CBICA_ABN_1', '68.285', '1278', 'STR']
# ['Brats18_CBICA_ABM_1', '69.912', '503', 'GTR']
# ['Brats18_CBICA_ABE_1', '67.126', '269', 'GTR']
# ['Brats18_CBICA_ABB_1', '68.493', '465', 'GTR']
# ['Brats18_CBICA_AAP_1', '39.068', '788', 'GTR']
# ['Brats18_CBICA_AAL_1', '54.301', '464', 'GTR']
# ['Brats18_CBICA_AAG_1', '52.263', '616', 'GTR']
# ['Brats18_CBICA_AAB_1', '60.463', '289', 'GTR']
# Processed 164 lines.
# 55 64 44

# %%
def SurvPredNet(input_img,age_m):
    #input_img = BatchNormalization()(input_img)
    a1 = Conv2D(16,kernel_size = (3,3) , padding='same')(input_img)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(24,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = MaxPooling2D(pool_size = (2,2) , strides = (2,2))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding='same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (6,6) , strides = (1,1))(a1)
    
    a1 = Conv2D(32,kernel_size = (3,3) , padding = 'same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (5,5) , strides = (1,1))(a1)
    a1 = Conv2D(32,kernel_size = (3,3) , padding = 'same')(a1)
    a1 = BatchNormalization()(a1)
    a1 = Activation('relu')(a1)
    
    a1 = AveragePooling2D(pool_size = (6,6) , strides = (1,1))(a1)
    
    a1 = Flatten()(a1)
    a1 = concatenate([a1,age_m])
    a1 = BatchNormalization()(a1)
    
    a1 = Dense(32,activation = 'relu')(a1)
    a1 = Dense(16,activation = 'relu')(a1)
    outputs = Dense(3,activation = 'softmax')(a1)
    
    model = Model(inputs = [input_img,age_m] , outputs = outputs)
    
    return model

# %%
input_img = Input((240,240,5))
age_m = Input((1))
model = SurvPredNet(input_img,age_m)
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 240, 240, 5) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 240, 240, 16) 736         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 240, 240, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 240, 240, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 120, 120, 16) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 120, 120, 24) 3480        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 120, 120, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 120, 120, 24) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 60, 60, 24)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 60, 60, 32)   6944        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 60, 60, 32)   128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 60, 60, 32)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 30, 30, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 30, 30, 32)   9248        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 30, 30, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 30, 30, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 15, 15, 32)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 15, 15, 32)   9248        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15, 15, 32)   128         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15, 15, 32)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 10, 10, 32)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 10, 10, 32)   9248        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 10, 10, 32)   128         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 10, 32)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 6, 6, 32)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 6, 6, 32)     9248        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 6, 6, 32)     128         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6, 6, 32)     0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 1, 1, 32)     0           activation_6[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 32)           0           average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 33)           0           flatten[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 33)           132         concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1088        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           528         dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 3)            51          dense_1[0][0]
# ==================================================================================================
# Total params: 50,751
# Trainable params: 50,285
# Non-trainable params: 466
# __________________________________________________________________________________________________

# %%
path = 'E:/MICCAI_BraTS_2018_Data_Training/HGG'
all_images = os.listdir(path)
#print(len(all_images))
all_images.sort()

def standardize(image):

  standardized_image = np.zeros(image.shape)

  #
 
      # iterate over the `z` dimension
  for z in range(image.shape[2]):
      # get a slice of the image
      # at channel c and z-th dimension `z`
      image_slice = image[:,:,z]

      # subtract the mean from image_slice
      centered = image_slice - np.mean(image_slice)
     
      # divide by the standard deviation (only if it is different from zero)
      if(np.std(centered)!=0):
          centered = centered/np.std(centered)

      # update  the slice of standardized image
      # with the scaled centered and scaled image
      standardized_image[:, :, z] = centered

  ### END CODE HERE ###

  return standardized_image

# %%
cnt = 0
for image_num in range(170):
    image1 = all_images[image_num]
    if image1 in days_dict:
        cnt += 1
        
print(cnt)
# Out:
# 134

# %%
loss_hist = []
accu_hist = []
epoch_wise_loss = []
epoch_wise_accu = []
#for epochs in range(45):
epoch_loss = 0
epoch_accu = 0
input_to_model = np.zeros((134,240,240,5))
age = np.zeros((134,1))
ground_truth = np.zeros((134,3))
cnt = 0
for image_num in range(170):
    #print(epochs)
    #print("image_num ",image_num)
    #print("cnt" ,cnt)
    data = np.zeros((240,240,155,4))
    image_data2=np.zeros((240,240,155))

    # data preprocessing starts here

    x = all_images[image_num]
    
    if x in days_dict:
        #print(cnt)
        #print(x)
        folder_path = path + '/' + x;
        modalities = os.listdir(folder_path)
        modalities.sort()
        #data = []
        w = 0
        for j in range(len(modalities)):
          #print(modalities[j])

          image_path = folder_path + '/' + modalities[j]
          if not(image_path.find('seg.nii') == -1):
            img = nib.load(image_path);
            image_data2 = img.get_data()
            image_data2 = np.asarray(image_data2)
            #print("Entered ground truth")
          else:
            img = nib.load(image_path);
            image_data = img.get_data()
            image_data = np.asarray(image_data)
            image_data = standardize(image_data)
            data[:,:,:,w] = image_data
            #print("Entered modality")
            w = w+1

        #print(data.shape)
        #print(image_data2.shape)
        image_data2[image_data2 == 4] = 3

        input_to_model[cnt,:,:,:4] = data[:,:,75,:]
        input_to_model[cnt,:,:,4] = image_data2[:,:,75]
        #age = np.zeros((1,1))
        age[cnt,0] = float(age_dict[x])
        days = int(days_dict[x])
        

        #ground_truth = np.zeros((1,3))
        #print(age[cnt,0])

        if int(days) < 300:
            ground_truth[cnt,0] = 1
        elif (int(days) >= 300 and int(days) <= 450):
            ground_truth[cnt,1] = 1
        else:
            ground_truth[cnt,2] = 1 
        
        #print(ground_truth[cnt])
        cnt += 1
        

    #y_to = keras.utils.to_categorical(y_to,num_classes=4)
history = model.fit(x=[input_to_model,age],y=ground_truth, epochs = 80 , batch_size = 64)
print(history.history['loss'])
#epoch_loss += history.history['loss'][0]
#epoch_accu += history.history['accuracy'][0]

#loss_hist.append(history.history['loss'])
#accu_hist.append(history.history['accuracy'])
# Out:
# <ipython-input-8-61f813f79368>:42: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image_data = img.get_data()
# <ipython-input-8-61f813f79368>:37: DeprecationWarning: get_data() is deprecated in favor of get_fdata(), which has a more predictable return type. To obtain get_data() behavior going forward, use numpy.asanyarray(img.dataobj).
#
# * deprecated from version: 3.0
# * Will raise <class 'nibabel.deprecator.ExpiredDeprecationError'> as of version: 5.0
#   image_data2 = img.get_data()
# Epoch 1/80
# 3/3 [==============================] - 2s 758ms/step - loss: 1.2798 - accuracy: 0.3284
# Epoch 2/80
# 3/3 [==============================] - 2s 734ms/step - loss: 1.0631 - accuracy: 0.4403
# Epoch 3/80
# 3/3 [==============================] - 2s 723ms/step - loss: 0.9598 - accuracy: 0.5149
# Epoch 4/80
# 3/3 [==============================] - 2s 736ms/step - loss: 0.9391 - accuracy: 0.5597
# Epoch 5/80
# 3/3 [==============================] - 2s 732ms/step - loss: 0.8846 - accuracy: 0.6269
# Epoch 6/80
# 3/3 [==============================] - 2s 764ms/step - loss: 0.8464 - accuracy: 0.6194
# Epoch 7/80
# 3/3 [==============================] - 2s 727ms/step - loss: 0.8323 - accuracy: 0.6343
# Epoch 8/80
# 3/3 [==============================] - 2s 751ms/step - loss: 0.7893 - accuracy: 0.6567
# Epoch 9/80
# 3/3 [==============================] - 2s 741ms/step - loss: 0.7805 - accuracy: 0.6343
# Epoch 10/80
# 3/3 [==============================] - 2s 761ms/step - loss: 0.8236 - accuracy: 0.6194
# Epoch 11/80
# 3/3 [==============================] - 2s 776ms/step - loss: 0.7690 - accuracy: 0.6418
# Epoch 12/80
# 3/3 [==============================] - 2s 737ms/step - loss: 0.8116 - accuracy: 0.6493
# Epoch 13/80
# 3/3 [==============================] - 2s 768ms/step - loss: 0.7442 - accuracy: 0.6791
# Epoch 14/80
# 3/3 [==============================] - 2s 750ms/step - loss: 0.7018 - accuracy: 0.6791
# Epoch 15/80
# 3/3 [==============================] - 2s 750ms/step - loss: 0.6417 - accuracy: 0.7015
# Epoch 16/80
# 3/3 [==============================] - 2s 772ms/step - loss: 0.6494 - accuracy: 0.7313
# Epoch 17/80
# 3/3 [==============================] - 2s 758ms/step - loss: 0.6111 - accuracy: 0.7612
# Epoch 18/80
# 3/3 [==============================] - 2s 740ms/step - loss: 0.6595 - accuracy: 0.7239
# Epoch 19/80
# 3/3 [==============================] - 2s 741ms/step - loss: 0.5862 - accuracy: 0.7463
# Epoch 20/80
# 3/3 [==============================] - 2s 751ms/step - loss: 0.5594 - accuracy: 0.7687
# Epoch 21/80
# 3/3 [==============================] - 2s 767ms/step - loss: 0.4916 - accuracy: 0.8284
# Epoch 22/80
# 3/3 [==============================] - 2s 742ms/step - loss: 0.4659 - accuracy: 0.8284
# Epoch 23/80
# 3/3 [==============================] - 2s 782ms/step - loss: 0.4164 - accuracy: 0.8955
# Epoch 24/80
# 3/3 [==============================] - 2s 754ms/step - loss: 0.4145 - accuracy: 0.8657
# Epoch 25/80
# 3/3 [==============================] - 2s 767ms/step - loss: 0.4368 - accuracy: 0.8358
# Epoch 26/80
# 3/3 [==============================] - 2s 766ms/step - loss: 0.4117 - accuracy: 0.8433
# Epoch 27/80
# 3/3 [==============================] - 2s 749ms/step - loss: 0.3958 - accuracy: 0.8881
# Epoch 28/80
# 3/3 [==============================] - 2s 776ms/step - loss: 0.5222 - accuracy: 0.8358
# Epoch 29/80
# 3/3 [==============================] - 2s 772ms/step - loss: 0.4819 - accuracy: 0.8433
# Epoch 30/80
# 3/3 [==============================] - 2s 757ms/step - loss: 0.4010 - accuracy: 0.8582
# Epoch 31/80
# 3/3 [==============================] - 2s 737ms/step - loss: 0.3510 - accuracy: 0.8881
# Epoch 32/80
# 3/3 [==============================] - 2s 779ms/step - loss: 0.3897 - accuracy: 0.8731
# Epoch 33/80
# 3/3 [==============================] - 2s 773ms/step - loss: 0.3956 - accuracy: 0.8507
# Epoch 34/80
# 3/3 [==============================] - 2s 763ms/step - loss: 0.3600 - accuracy: 0.8657
# Epoch 35/80
# 3/3 [==============================] - 2s 809ms/step - loss: 0.4510 - accuracy: 0.8433
# Epoch 36/80
# 3/3 [==============================] - 2s 755ms/step - loss: 0.3854 - accuracy: 0.8507
# Epoch 37/80
# 3/3 [==============================] - 2s 750ms/step - loss: 0.4110 - accuracy: 0.8806
# Epoch 38/80
# 3/3 [==============================] - 2s 808ms/step - loss: 0.3303 - accuracy: 0.9179
# Epoch 39/80
# 3/3 [==============================] - 2s 800ms/step - loss: 0.2903 - accuracy: 0.9328
# Epoch 40/80
# 3/3 [==============================] - 2s 801ms/step - loss: 0.3488 - accuracy: 0.8806
# Epoch 41/80
# 3/3 [==============================] - 2s 779ms/step - loss: 0.4507 - accuracy: 0.8209
# Epoch 42/80
# 3/3 [==============================] - 2s 775ms/step - loss: 0.4162 - accuracy: 0.8507
# Epoch 43/80
# 3/3 [==============================] - 2s 754ms/step - loss: 0.3373 - accuracy: 0.8731
# Epoch 44/80
# 3/3 [==============================] - 2s 777ms/step - loss: 0.3805 - accuracy: 0.8507
# Epoch 45/80
# 3/3 [==============================] - 2s 757ms/step - loss: 0.3418 - accuracy: 0.8657
# Epoch 46/80
# 3/3 [==============================] - 2s 759ms/step - loss: 0.2469 - accuracy: 0.9627
# Epoch 47/80
# 3/3 [==============================] - 2s 795ms/step - loss: 0.2578 - accuracy: 0.9328
# Epoch 48/80
# 3/3 [==============================] - 2s 765ms/step - loss: 0.2486 - accuracy: 0.9478
# Epoch 49/80
# 3/3 [==============================] - 2s 759ms/step - loss: 0.2836 - accuracy: 0.9254
# Epoch 50/80
# 3/3 [==============================] - 2s 763ms/step - loss: 0.3749 - accuracy: 0.8731
# Epoch 51/80
# 3/3 [==============================] - 2s 759ms/step - loss: 0.3707 - accuracy: 0.8507
# Epoch 52/80
# 3/3 [==============================] - 2s 791ms/step - loss: 0.3344 - accuracy: 0.8507
# Epoch 53/80
# 3/3 [==============================] - 2s 756ms/step - loss: 0.3623 - accuracy: 0.8657
# Epoch 54/80
# 3/3 [==============================] - 2s 797ms/step - loss: 0.2880 - accuracy: 0.9104
# Epoch 55/80
# 3/3 [==============================] - 2s 762ms/step - loss: 0.3025 - accuracy: 0.8955
# Epoch 56/80
# 3/3 [==============================] - 2s 759ms/step - loss: 0.2812 - accuracy: 0.9104
# Epoch 57/80
# 3/3 [==============================] - 2s 773ms/step - loss: 0.2372 - accuracy: 0.9254
# Epoch 58/80
# 3/3 [==============================] - 2s 767ms/step - loss: 0.2007 - accuracy: 0.9478
# Epoch 59/80
# 3/3 [==============================] - 2s 792ms/step - loss: 0.1965 - accuracy: 0.9478
# Epoch 60/80
# 3/3 [==============================] - 2s 773ms/step - loss: 0.1765 - accuracy: 0.9478
# Epoch 61/80
# 3/3 [==============================] - 2s 772ms/step - loss: 0.1625 - accuracy: 0.9627
# Epoch 62/80
# 3/3 [==============================] - 2s 755ms/step - loss: 0.2055 - accuracy: 0.9328
# Epoch 63/80
# 3/3 [==============================] - 2s 784ms/step - loss: 0.1221 - accuracy: 0.9701
# Epoch 64/80
# 3/3 [==============================] - 2s 770ms/step - loss: 0.1323 - accuracy: 0.9776
# Epoch 65/80
# 3/3 [==============================] - 2s 755ms/step - loss: 0.1379 - accuracy: 0.9552
# Epoch 66/80
# 3/3 [==============================] - 2s 759ms/step - loss: 0.0972 - accuracy: 0.9776
# Epoch 67/80
# 3/3 [==============================] - 2s 779ms/step - loss: 0.0905 - accuracy: 0.9776
# Epoch 68/80
# 3/3 [==============================] - 2s 770ms/step - loss: 0.0668 - accuracy: 1.0000
# Epoch 69/80
# 3/3 [==============================] - 2s 757ms/step - loss: 0.1892 - accuracy: 0.9478
# Epoch 70/80
# 3/3 [==============================] - 2s 769ms/step - loss: 0.3222 - accuracy: 0.8806
# Epoch 71/80
# 3/3 [==============================] - 2s 792ms/step - loss: 0.4095 - accuracy: 0.8582
# Epoch 72/80
# 3/3 [==============================] - 2s 773ms/step - loss: 0.2842 - accuracy: 0.9030
# Epoch 73/80
# 3/3 [==============================] - 2s 779ms/step - loss: 0.2713 - accuracy: 0.9104
# Epoch 74/80
# 3/3 [==============================] - 2s 769ms/step - loss: 0.1993 - accuracy: 0.9552
# Epoch 75/80
# 3/3 [==============================] - 2s 761ms/step - loss: 0.2101 - accuracy: 0.9254
# Epoch 76/80
# 3/3 [==============================] - 2s 774ms/step - loss: 0.3397 - accuracy: 0.8582
# Epoch 77/80
# 3/3 [==============================] - 2s 770ms/step - loss: 0.1870 - accuracy: 0.9627
# Epoch 78/80
# 3/3 [==============================] - 2s 797ms/step - loss: 0.1462 - accuracy: 0.9552
# Epoch 79/80
# 3/3 [==============================] - 2s 750ms/step - loss: 0.2258 - accuracy: 0.9104
# Epoch 80/80
# 3/3 [==============================] - 2s 761ms/step - loss: 0.2300 - accuracy: 0.9254
# [1.279779314994812, 1.0630948543548584, 0.9597853422164917, 0.9391427636146545, 0.8845754265785217, 0.8463558554649353, 0.8322587013244629, 0.789306104183197, 0.7804744243621826, 0.8236209154129028, 0.7690117955207825, 0.8116094470024109, 0.7441564798355103, 0.7017970085144043, 0.6416563391685486, 0.649441659450531, 0.6110833883285522, 0.6594662070274353, 0.5862242579460144, 0.5594020485877991, 0.4915870130062103, 0.46594056487083435, 0.41641122102737427, 0.4144990146160126, 0.4368273615837097, 0.4117136597633362, 0.3958340883255005, 0.5221741795539856, 0.4819444715976715, 0.40103447437286377, 0.35099369287490845, 0.3896864950656891, 0.3955540060997009, 0.36002764105796814, 0.45102936029434204, 0.38539355993270874, 0.4109916388988495, 0.33033546805381775, 0.2903287410736084, 0.3488073945045471, 0.45071202516555786, 0.41619864106178284, 0.3373051583766937, 0.3804900348186493, 0.3417944312095642, 0.24688398838043213, 0.25783321261405945, 0.24860785901546478, 0.2835642695426941, 0.3748886287212372, 0.3706852197647095, 0.3344171345233917, 0.3623467981815338, 0.2879864275455475, 0.3025059401988983, 0.281228244304657, 0.23717868328094482, 0.20073860883712769, 0.1965165138244629, 0.17652320861816406, 0.16245083510875702, 0.20550599694252014, 0.12211818248033524, 0.13233165442943573, 0.137942373752594, 0.097179114818573, 0.09045504778623581, 0.06680814176797867, 0.18916471302509308, 0.3221941292285919, 0.4095083475112915, 0.2841986119747162, 0.2712927460670471, 0.199306458234787, 0.2101220339536667, 0.33968594670295715, 0.1869964301586151, 0.14621147513389587, 0.225807324051857, 0.22997033596038818]

# %%
#epoch_loss = epoch_loss/180
#epoch_accu = epoch_accu/180

#epoch_wise_loss.append(epoch_loss)
#epoch_wise_accu.append(epoch_accu)
 
plt.plot(history.history['loss'])
plt.title('Model_loss vs epochs')
plt.ylabel('Loss')
plt.xlabel('epochs')
s = 'E:/MICCAI_BraTS_2018_Data_Training/epochwise_loss'
plt.savefig(s)
plt.show()
plt.close()

plt.plot(history.history['accuracy'])
plt.title('Model_Accuracy vs epochs')
plt.ylabel('Accuracy')
plt.xlabel('epochs')
s = 'E:/MICCAI_BraTS_2018_Data_Training/epochwise_accuracy'
plt.savefig(s)
plt.show()
plt.close()
