# %% [markdown]
# <a href="https://colab.research.google.com/github/divsal009/div/blob/master/Albumentations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import albumentations as A
import cv2

# Declare an augmentation pipeline
transform = A.Compose([
    A.RandomCrop(width=100, height=200),
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(p=0.2),
])

# %%
# Read an image with OpenCV and convert it to the RGB colorspace
image = cv2.imread("/content/Y1.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Augment an image
transformed = transform(image=image)
transformed_image = transformed["image"]

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=180x218 at 0x7F18AD158A90>

# %%
cv2_imshow(transformed_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x200 at 0x7F18D1F083D0>
